# %%
def groceryfunc(var):
    if var=="pulses":
        rate=500
    elif var=="spices":
        rate=150
    elif var=="dairy":
        rate=300
    elif var=="wheat":
        rate=400
    else:
        print("Invalid Value")

# %%
def electronicfunc():
    if bar=="Iron":
        rate=1000
    elif bar=="Fan":
        rate=1200
    elif bar=="AC":
        rate=2000
    elif bar=="Fridge":
        rate=5000
    else:
        print("Invalid Input")

# %%
def fandvfunc():
    if car=="Tomato" and car=="Potato":
        rate=90
    elif car=="Orange" and car=="Grapes" and car=="Apple":
        rate=100
    elif car=="Piyaz" and car=="Potato":
        rate=130
    else:
        print("Invalid Input")

# %%
grocery=[]
electronic=[]
cart=[]
fandv=[]
total=[]

print("Shopping Center Hare!")
print("Welcome to ecomerce store!")

while True:
    select=input("Which category you want to buy? \n1.grocery \n2.electronic \n3.fruit and veg:")
    if select=="1":
        while True:
            bucket=["pulses","spices","dairy","rice","wheat"]
            for i in bucket:
                print(i)
            var=input("Please mention what your want to buy from above list?").lower()
            rates=groceryfunc(var)
            total.append(rates)
            if var in bucket:
                print(f"bought item {var}, Rs.{rates}")
                grocery.append(var)
                
                rerun=input("Do you want to add more from grocery? (yes or no):").lower()
                if rerun=="yes":
                    continue
                else:
                    print("Ok Thank you for shopping grocery!")
                    break
            else:
                print("item not found in the bucket")
        rerun=input("Do you want to add more from store? (yes or no):").lower()
        if rerun=="yes":
            continue
        else:
            print("Thank you for Shopping!")
            break
    elif select=="2":
        print("Welcome to electronics")
    else:
        print("invalid input!")
        rerun=input("Do you want to add more from store? (yes or no):").lower()
        if rerun=="yes":
            continue
        else:
            print("Thank you For Shopping from us Bye!")
            break
        
   #break
# Out:
# Shopping Center Hare!
# Welcome to ecomerce store!
# Which category you want to buy?
# 1.grocery
# 2.electronic
# 3.fruit and veg: 1
# pulses
# spices
# dairy
# rice
# wheat
# Please mention what your want to buy from above list? pulses
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 18
#      16     print(i)
#      17 var=input("Please mention what your want to buy from above list?").lower()
# ---> 18 rates=groceryfunc(var)
#      19 total.append(rates)
#      20 if var in bucket:
#
# NameError: name 'groceryfunc' is not defined
